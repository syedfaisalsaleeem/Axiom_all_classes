# %%
from pandas import Series,DataFrame
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data_for_panda_exercise.csv')
df
# Out:
#      Student_Code  Degree                    Student_Name  Mid  Quiz_1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.columns
# Out:
# Index(['Student_Code', 'Degree', 'Student_Name', 'Mid', 'Quiz_1', 'Qui_ 2',
#        'Best_of_Quizzes', 'Assignmen_ 1', 'Assignment_2',
#        'Best_of_Assignments', 'Total_Sessional (50)', 'Final_(50)',
#        'Total_(100)', 'Grade'],
#       dtype='object')

# %%
df.ix().index
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-ca6ea4717219> in <module>
# ----> 1 df.ix().index
#
# AttributeError: '_IXIndexer' object has no attribute 'index'

# %%
df.tail()
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz_1  Qui_ 2  \
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best_of_Quizzes  Assignmen_ 1  Assignment_2  Best_of_Assignments  \
# 43                9           6.0           8.0                    8
# 44                7           9.0           NaN                    9
# 45                9           9.0           NaN                    9
# 46                8           8.0          10.0                   10
# 47                9           5.0           7.0                    7
#
#     Total_Sessional (50)  Final_(50)  Total_(100) Grade
# 43                    45        34.0           79     B
# ...

# %%
df.head(10)
# Out:
#     Student_Code  Degree      Student_Name  Mid  Quiz_1  Qui_ 2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0     6.0
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0     6.0
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0     6.0
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0     4.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best_of_Quizzes  Assignmen_ 1  Assignment_2  Best_of_Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# ...

# %%
df.groupby(['Best of Assignments']).count()
#groupby is used to group with respect to columns #usmei count show kardeye ek columns ki hisaab sai
#best of assignment sai student code 1 agar 0 ho
#groupby karke show karaha hai ek cluster bna kar
#har colums kai hissab sai count dikha raha hai
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-118-c44b939e881f> in <module>
# ----> 1 df.groupby(['Best of Assignments']).count()
#       2 #groupby is used to group with respect to columns #usmei count show kardeye ek columns ki hisaab sai
#       3 #best of assignment sai student code 1 agar 0 ho
#       4 #groupby karke show karaha hai ek cluster bna kar
#       5 #har colums kai hissab sai count dikha raha hai
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
# ...

# %%
df.groupby(['Final (50)']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-85b9a54ff7c8> in <module>
# ----> 1 df.groupby(['Final (50)']).count()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ...

# %%
df.groupby(['Student Name']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-9d7dea72b2c0> in <module>
# ----> 1 df.groupby(['Student Name']).count()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ...

# %%
df.groupby(['Best of Quizzes']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-cf2bf9fcce2e> in <module>
# ----> 1 df.groupby(['Best of Quizzes']).count()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ...

# %%
df.groupby(['Degree']).as_index
# Out:
# True

# %%
sum(df.Grade=='A') # 8 logon kai students A hai
# Out:
# 8

# %%
df[df.Grade=='B']
# Out:
#      Student_Code  Degree           Student_Name  Mid  Quiz_1  Qui_ 2  \
# 0    022-14-19987  BS(CS)            Abdul Basit   28     8.0     3.0
# 4   022-14-110648  BS(CS)        Ahsan Ali Vohra   27     7.0     6.0
# 5   022-14-110232  BS(CS)            Ameer Hamza   25     9.0     6.0
# 6   022-14-110588  BS(CS)          Anas Ali Khan   28     5.0     6.0
# 11  022-14-110591  BS(CS)            Habib Ullah   28     8.0     5.0
# 12  022-15-110994  BS(CS)    Hafiza Tooba Akbani   23     7.0     5.0
# 16  022-14-110596  BS(CS)           Hassam Ahmed   23     5.0     5.0
# 17  022-14-110396  BS(CS)           Khalid Anwer   20     8.0     5.0
# 20  022-14-110412  BS(CS)         Muhammad Aamir   24     7.0     6.0
# 24  022-14-110215  BS(CS)         Muhammad Bilal   28     5.0     4.0
# 27  022-14-110452  BS(CS)    Muhammad Osama Khan   27     8.0     6.0
# 30  022-14-110401  BS(CS)        Muhammad Shozab   23     8.0     6.0
# ...

# %%
df[(df.Grade=='B') & (df.Mid==28)]
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz_1  Qui_ 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 6   022-14-110588  BS(CS)      Anas Ali Khan   28     5.0     6.0
# 11  022-14-110591  BS(CS)        Habib Ullah   28     8.0     5.0
# 24  022-14-110215  BS(CS)     Muhammad Bilal   28     5.0     4.0
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
#
#     Best_of_Quizzes  Assignmen_ 1  Assignment_2  Best_of_Assignments  \
# 0                 8           7.0           9.0                    9
# 6                 6           8.0          10.0                   10
# 11                8           5.0           NaN                    5
# 24                5           9.0          11.0                   11
# 43                9           6.0           8.0                    8
#
#     Total_Sessional (50)  Final_(50)  Total_(100) Grade
# 0                     45        25.0           70     B
# ...

# %%
df.columns
# Out:
# Index(['Student_Code', 'Degree', 'Student_Name', 'Mid', 'Quiz_1', 'Qui_ 2',
#        'Best_of_Quizzes', 'Assignmen_ 1', 'Assignment_2',
#        'Best_of_Assignments', 'Total_Sessional (50)', 'Final_(50)',
#        'Total_(100)', 'Grade'],
#       dtype='object')

# %%
x="faisal"
x.startswith('f')
# Out:
# True

# %%
df[(df.Grade == 'A') & (df.Student_Name.str.startswith('A'))]
# Out:
#     Student_Code  Degree      Student_Name  Mid  Quiz_1  Qui_ 2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best_of_Quizzes  Assignmen_ 1  Assignment_2  Best_of_Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total_Sessional (50)  Final_(50)  Total_(100) Grade
# 7                    45        40.0           85     A
# 9                    44        40.0           84     A

# %%
df.columns
# Out:
# Index(['Student_Code', 'Degree', 'Student_Name', 'Mid', 'Quiz_1', 'Qui_ 2',
#        'Best_of_Quizzes', 'Assignmen_ 1', 'Assignment_2',
#        'Best_of_Assignments', 'Total_Sessional (50)', 'Final_(50)',
#        'Total_(100)', 'Grade'],
#       dtype='object')

# %%
df
# Out:
#      Student_Code  Degree                    Student_Name  Mid  Quiz_1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...
